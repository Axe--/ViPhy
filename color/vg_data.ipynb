# %% [markdown]
# # Object → Colors
#
# Extract Object Names & Color distribution from caption + image.
#
# ### "Visualize Each Stage of Pipeline!"
#
# ####  Incremental Development
#
# - Objects with `uni`, `bi`, `tri` & `any`:  **1000**
# - Objects with Qualifiers (context, state): **3000**
# - Refine names via embedding clusters:    **5000**
# - Later use Entropy for 'object selection'
#   (e.g. shoes: party shoes vs tennis shoes)
#
# Leverage *ConceptNet-KB* for verifying object names.
#
# ----
#
#
# #### Object Name Extraction
#
# - Fetch object names (and frequency) using POS Tags
# - Track image & region IDs for each object name
# - Maintain a flag indicating the presence of object name in ConceptNet

# %%
import requests
import numpy as np
from tqdm import tqdm
from os.path import join as osj
from utils import read_json, save_json
from data_dev import ColorDataDev
from collections import OrderedDict, Counter

DATA_DIR = '../../../Datasets/Visual_Genome'

# %%
raw_data = read_json(osj(DATA_DIR, 'region_graphs.json'))

# %%
caps_img = [len(x['regions']) for x in raw_data]

_ = int(np.mean(caps_img))
__ = int(np.std(caps_img))

f"Captions per Image: µ = {_}, σ = {__}"
# Out:
# 'Captions per Image: µ = 50, σ = 9'

# %% [markdown]
# ## Region Data

# %%
def _print(l: list):
    for e in l:
        print(e)
    print()

_idx = 0

d = raw_data[_idx]['regions']

for x in d:
    print(x['phrase'], '\n')

    print('Objects:')
    _print(x['objects'])

    print('Synsets:')
    _print(x['synsets'])

    print('Relations:')
    _print(x['relationships'])
    print('\n--------------------\n')
# Out:
# the clock is green in colour
#
# Objects:
# {'name': 'clock', 'h': 339, 'object_id': 1058498, 'synsets': ['clock.n.01'], 'w': 79, 'y': 91, 'x': 421}
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 9, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
# {'entity_idx_start': 22, 'entity_idx_end': 28, 'entity_name': 'colour', 'synset_name': 'color.n.04'}
#
# Relations:
#
#
# --------------------
#
# shade is along the street
#
# Objects:
# {'name': 'street', 'h': 262, 'object_id': 5046, 'synsets': ['street.n.01'], 'w': 714, 'y': 328, 'x': 77}
# {'name': 'shade', 'h': 192, 'object_id': 5045, 'synsets': ['shade.n.01'], 'w': 274, 'y': 338, 'x': 119}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'shade', 'synset_name': 'shade.n.01'}
# {'entity_idx_start': 19, 'entity_idx_end': 25, 'entity_name': 'street', 'synset_name': 'street.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'ON', 'relationship_id': 15927, 'object_id': 5046, 'subject_id': 5045}
#
#
# --------------------
#
# man is wearing sneakers
#
# Objects:
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
# {'name': 'sneakers', 'h': 26, 'object_id': 5048, 'synsets': ['gym_shoe.n.01'], 'w': 52, 'y': 489, 'x': 243}
#
# Synsets:
# {'entity_idx_start': 15, 'entity_idx_end': 23, 'entity_name': 'sneakers', 'synset_name': 'gym_shoe.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
# {'synsets': ['wear.v.01'], 'predicate': 'wears', 'relationship_id': 15928, 'object_id': 5048, 'subject_id': 1058529}
#
#
# --------------------
#
# cars headlights are off
#
# Objects:
# {'name': 'headlight', 'h': 15, 'object_id': 5050, 'synsets': ['headlight.n.01'], 'w': 23, 'y': 366, 'x': 514}
# {'name': 'car', 'h': 98, 'object_id': 5049, 'synsets': ['car.n.01'], 'w': 74, 'y': 315, 'x': 479}
#
# Synsets:
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'has', 'relationship_id': 15929, 'object_id': 5050, 'subject_id': 5049}
#
#
# --------------------
#
# bikes are parked at the far edge
#
# Objects:
# {'name': 'bike', 'h': 34, 'object_id': 5051, 'synsets': ['bicycle.n.01'], 'w': 28, 'y': 319, 'x': 318}
# {'name': 'bike', 'h': 35, 'object_id': 1058535, 'synsets': ['bicycle.n.01'], 'w': 29, 'y': 319, 'x': 334}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'bikes', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 28, 'entity_idx_end': 32, 'entity_name': 'edge', 'synset_name': 'edge.n.01'}
#
# Relations:
#
#
# --------------------
#
# A sign on the facade of the building
#
# Objects:
# {'name': 'sign', 'h': 182, 'object_id': 1058507, 'synsets': ['sign.n.02'], 'w': 88, 'y': 13, 'x': 118}
# {'name': 'building', 'h': 536, 'object_id': 1058508, 'synsets': ['building.n.01'], 'w': 218, 'y': 2, 'x': 1}
#
# Synsets:
# {'entity_idx_start': 28, 'entity_idx_end': 36, 'entity_name': 'building', 'synset_name': 'building.n.01'}
# {'entity_idx_start': 14, 'entity_idx_end': 20, 'entity_name': 'facade', 'synset_name': 'facade.n.01'}
# {'entity_idx_start': 2, 'entity_idx_end': 6, 'entity_name': 'sign', 'synset_name': 'sign.n.02'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'ON', 'relationship_id': 15930, 'object_id': 1058508, 'subject_id': 1058507}
#
#
# --------------------
#
# A tree trunk on the sidewalk
#
# Objects:
# {'name': 'tree trunk', 'h': 327, 'object_id': 5055, 'synsets': ['trunk.n.01'], 'w': 87, 'y': 234, 'x': 622}
# {'name': 'sidewalk', 'h': 266, 'object_id': 1058534, 'synsets': ['sidewalk.n.01'], 'w': 722, 'y': 331, 'x': 77}
#
# Synsets:
# {'entity_idx_start': 20, 'entity_idx_end': 28, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
# {'entity_idx_start': 2, 'entity_idx_end': 12, 'entity_name': 'tree trunk', 'synset_name': 'trunk.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'ON', 'relationship_id': 15931, 'object_id': 1058534, 'subject_id': 5055}
#
#
# --------------------
#
# A man in a red shirt
#
# Objects:
# {'name': 'shirt', 'h': 101, 'object_id': 1058511, 'synsets': ['shirt.n.01'], 'w': 59, 'y': 289, 'x': 241}
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 15, 'entity_idx_end': 20, 'entity_name': 'shirt', 'synset_name': 'shirt.n.01'}
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'has', 'relationship_id': 15932, 'object_id': 1058511, 'subject_id': 1058529}
#
#
# --------------------
#
# A brick sidewalk beside the street
#
# Objects:
# {'name': 'sidewalk', 'h': 266, 'object_id': 1058534, 'synsets': ['sidewalk.n.01'], 'w': 722, 'y': 331, 'x': 77}
# {'name': 'street', 'h': 233, 'object_id': 1058539, 'synsets': ['street.n.01'], 'w': 440, 'y': 283, 'x': 358}
#
# Synsets:
# {'entity_idx_start': 28, 'entity_idx_end': 34, 'entity_name': 'street', 'synset_name': 'street.n.01'}
#
# Relations:
# {'synsets': ['next.r.01'], 'predicate': 'next to', 'relationship_id': 15933, 'object_id': 1058539, 'subject_id': 1058534}
#
#
# --------------------
#
# The back of a white car
#
# Objects:
# {'name': 'car', 'h': 174, 'object_id': 1058515, 'synsets': ['car.n.01'], 'w': 91, 'y': 342, 'x': 708}
# {'name': 'back', 'h': 170, 'object_id': 5060, 'synsets': ['back.n.01'], 'w': 67, 'y': 339, 'x': 721}
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 8, 'entity_name': 'back', 'synset_name': 'back.n.01'}
# {'entity_idx_start': 20, 'entity_idx_end': 23, 'entity_name': 'car', 'synset_name': 'car.n.01'}
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'has', 'relationship_id': 15934, 'object_id': 5060, 'subject_id': 1058515}
#
#
# --------------------
#
# a man is wearing glasses
#
# Objects:
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
# {'name': 'glasses', 'h': 12, 'object_id': 1058518, 'synsets': ['spectacles.n.01'], 'w': 20, 'y': 268, 'x': 271}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 17, 'entity_idx_end': 24, 'entity_name': 'glasses', 'synset_name': 'spectacles.n.01'}
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'has', 'relationship_id': 15935, 'object_id': 1058518, 'subject_id': 1058529}
#
#
# --------------------
#
# a parking meter is on the sidewalk
#
# Objects:
# {'name': 'parking meter', 'h': 143, 'object_id': 1058519, 'synsets': ['parking_meter.n.01'], 'w': 32, 'y': 327, 'x': 574}
# {'name': 'sidewalk', 'h': 266, 'object_id': 1058534, 'synsets': ['sidewalk.n.01'], 'w': 722, 'y': 331, 'x': 77}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 15, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
# {'entity_idx_start': 26, 'entity_idx_end': 34, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'ON', 'relationship_id': 15936, 'object_id': 1058534, 'subject_id': 1058519}
#
#
# --------------------
#
# bicycles are in the background
#
# Objects:
# {'name': 'bike', 'h': 34, 'object_id': 5051, 'synsets': ['bicycle.n.01'], 'w': 28, 'y': 319, 'x': 318}
# {'name': 'bike', 'h': 35, 'object_id': 1058535, 'synsets': ['bicycle.n.01'], 'w': 29, 'y': 319, 'x': 334}
#
# Synsets:
# {'entity_idx_start': 20, 'entity_idx_end': 30, 'entity_name': 'background', 'synset_name': 'background.n.02'}
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'bicycles', 'synset_name': 'bicycle.n.01'}
#
# Relations:
#
#
# --------------------
#
# a man wears grey shoes
#
# Objects:
# {'name': 'sneakers', 'h': 26, 'object_id': 5048, 'synsets': ['gym_shoe.n.01'], 'w': 52, 'y': 489, 'x': 243}
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 17, 'entity_idx_end': 22, 'entity_name': 'shoes', 'synset_name': 'shoe.n.01'}
#
# Relations:
# {'synsets': ['wear.v.01'], 'predicate': 'wears', 'relationship_id': 15937, 'object_id': 5048, 'subject_id': 1058529}
#
#
# --------------------
#
# a man has brown shoes on
#
# Objects:
# {'name': 'shoes', 'h': 34, 'object_id': 1058525, 'synsets': ['shoe.n.01'], 'w': 46, 'y': 481, 'x': 391}
# {'name': 'man', 'h': 251, 'object_id': 1058532, 'synsets': ['man.n.01'], 'w': 75, 'y': 264, 'x': 372}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 16, 'entity_idx_end': 21, 'entity_name': 'shoes', 'synset_name': 'shoe.n.01'}
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'has', 'relationship_id': 15938, 'object_id': 1058525, 'subject_id': 1058532}
#
#
# --------------------
#
# A man dressed in a red shirt and black pants.
#
# Objects:
# {'name': 'shirt', 'h': 101, 'object_id': 1058511, 'synsets': ['shirt.n.01'], 'w': 59, 'y': 289, 'x': 241}
# {'name': 'pants', 'h': 118, 'object_id': 1058528, 'synsets': ['trouser.n.01'], 'w': 38, 'y': 384, 'x': 245}
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 23, 'entity_idx_end': 28, 'entity_name': 'shirt', 'synset_name': 'shirt.n.01'}
# {'entity_idx_start': 39, 'entity_idx_end': 44, 'entity_name': 'pants', 'synset_name': 'trouser.n.01'}
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'has', 'relationship_id': 15939, 'object_id': 1058511, 'subject_id': 1058529}
# {'synsets': ['wear.v.01'], 'predicate': 'wears', 'relationship_id': 15940, 'object_id': 1058528, 'subject_id': 1058529}
#
#
# --------------------
#
# A man wearing a gray jacket and gray pants.
#
# Objects:
# {'name': 'jacket', 'h': 97, 'object_id': 1058530, 'synsets': ['jacket.n.01'], 'w': 89, 'y': 296, 'x': 356}
# {'name': 'pants', 'h': 128, 'object_id': 1058531, 'synsets': ['trouser.n.01'], 'w': 54, 'y': 369, 'x': 382}
# {'name': 'man', 'h': 251, 'object_id': 1058532, 'synsets': ['man.n.01'], 'w': 75, 'y': 264, 'x': 372}
#
# Synsets:
# {'entity_idx_start': 21, 'entity_idx_end': 27, 'entity_name': 'jacket', 'synset_name': 'jacket.n.01'}
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 37, 'entity_idx_end': 42, 'entity_name': 'pants', 'synset_name': 'trouser.n.01'}
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'has', 'relationship_id': 15941, 'object_id': 1058530, 'subject_id': 1058532}
# {'synsets': ['have.v.01'], 'predicate': 'has', 'relationship_id': 15942, 'object_id': 1058531, 'subject_id': 1058532}
#
#
# --------------------
#
# A bicycle parked on the sidewalk.
#
# Objects:
# {'name': 'bike', 'h': 34, 'object_id': 5051, 'synsets': ['bicycle.n.01'], 'w': 28, 'y': 319, 'x': 318}
# {'name': 'sidewalk', 'h': 266, 'object_id': 1058534, 'synsets': ['sidewalk.n.01'], 'w': 722, 'y': 331, 'x': 77}
# {'name': 'bike', 'h': 35, 'object_id': 1058535, 'synsets': ['bicycle.n.01'], 'w': 29, 'y': 319, 'x': 334}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 9, 'entity_name': 'bicycle', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 24, 'entity_idx_end': 32, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'parked on', 'relationship_id': 15943, 'object_id': 1058534, 'subject_id': 5051}
# {'synsets': ['along.r.01'], 'predicate': 'parked on', 'relationship_id': 15944, 'object_id': 1058534, 'subject_id': 1058535}
#
#
# --------------------
#
# A white work truck parked on the street.
#
# Objects:
# {'name': 'work truck', 'h': 185, 'object_id': 1058536, 'synsets': [], 'w': 265, 'y': 271, 'x': 521}
# {'name': 'street', 'h': 233, 'object_id': 1058539, 'synsets': ['street.n.01'], 'w': 440, 'y': 283, 'x': 358}
#
# Synsets:
# {'entity_idx_start': 33, 'entity_idx_end': 39, 'entity_name': 'street', 'synset_name': 'street.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'parked on', 'relationship_id': 15945, 'object_id': 1058539, 'subject_id': 1058536}
#
#
# --------------------
#
# A white car parked on the street.
#
# Objects:
# {'name': 'car', 'h': 174, 'object_id': 1058515, 'synsets': ['car.n.01'], 'w': 91, 'y': 342, 'x': 708}
# {'name': 'street', 'h': 233, 'object_id': 1058539, 'synsets': ['street.n.01'], 'w': 440, 'y': 283, 'x': 358}
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 11, 'entity_name': 'car', 'synset_name': 'car.n.01'}
# {'entity_idx_start': 26, 'entity_idx_end': 32, 'entity_name': 'street', 'synset_name': 'street.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'parked on', 'relationship_id': 15946, 'object_id': 1058539, 'subject_id': 1058515}
#
#
# --------------------
#
# guy wearing a red shirt
#
# Objects:
# {'name': 'shirt', 'h': 101, 'object_id': 1058511, 'synsets': ['shirt.n.01'], 'w': 59, 'y': 289, 'x': 241}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'guy', 'synset_name': 'guy.n.01'}
# {'entity_idx_start': 18, 'entity_idx_end': 23, 'entity_name': 'shirt', 'synset_name': 'shirt.n.01'}
#
# Relations:
#
#
# --------------------
#
# black sign on front of building
#
# Objects:
# {'name': 'sign', 'h': 182, 'object_id': 1058507, 'synsets': ['sign.n.02'], 'w': 88, 'y': 13, 'x': 118}
#
# Synsets:
# {'entity_idx_start': 23, 'entity_idx_end': 31, 'entity_name': 'building', 'synset_name': 'building.n.01'}
# {'entity_idx_start': 6, 'entity_idx_end': 10, 'entity_name': 'sign', 'synset_name': 'sign.n.02'}
#
# Relations:
#
#
# --------------------
#
# bicycles on the sidewalk
#
# Objects:
# {'name': 'sidewalk', 'h': 189, 'object_id': 3798575, 'synsets': ['sidewalk.n.01'], 'w': 50, 'y': 318, 'x': 343}
# {'name': 'bike', 'h': 35, 'object_id': 1058535, 'synsets': ['bicycle.n.01'], 'w': 29, 'y': 319, 'x': 334}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'bicycles', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 16, 'entity_idx_end': 24, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'ON', 'relationship_id': 4265923, 'object_id': 3798575, 'subject_id': 1058535}
#
#
# --------------------
#
# parking meter on the sidewalk
#
# Objects:
# {'name': 'man', 'h': 251, 'object_id': 1058532, 'synsets': ['man.n.01'], 'w': 75, 'y': 264, 'x': 372}
# {'name': 'parking meter', 'h': 143, 'object_id': 1058519, 'synsets': ['parking_meter.n.01'], 'w': 32, 'y': 327, 'x': 574}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 13, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
# {'entity_idx_start': 21, 'entity_idx_end': 29, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
# {'synsets': ['behind.r.01'], 'predicate': 'behind', 'relationship_id': 3186256, 'object_id': 1058532, 'subject_id': 1058519}
#
#
# --------------------
#
# guy holding hand to his chin
#
# Objects:
# {'name': 'chin', 'h': 9, 'object_id': 1058541, 'synsets': ['chin.n.01'], 'w': 11, 'y': 288, 'x': 399}
# {'name': 'guy', 'h': 250, 'object_id': 1058540, 'synsets': ['guy.n.01'], 'w': 82, 'y': 264, 'x': 369}
#
# Synsets:
# {'entity_idx_start': 24, 'entity_idx_end': 28, 'entity_name': 'chin', 'synset_name': 'chin.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'guy', 'synset_name': 'guy.n.01'}
# {'entity_idx_start': 12, 'entity_idx_end': 16, 'entity_name': 'hand', 'synset_name': 'hand.n.01'}
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'holding', 'relationship_id': 3186257, 'object_id': 1058541, 'subject_id': 1058540}
#
#
# --------------------
#
# he has an orange tshirt
#
# Objects:
# {'name': 'shirt', 'h': 101, 'object_id': 1058511, 'synsets': ['shirt.n.01'], 'w': 59, 'y': 289, 'x': 241}
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# he has brown shoes
#
# Objects:
# {'name': 'shoes', 'h': 34, 'object_id': 1058525, 'synsets': ['shoe.n.01'], 'w': 46, 'y': 481, 'x': 391}
#
# Synsets:
# {'entity_idx_start': 13, 'entity_idx_end': 18, 'entity_name': 'shoes', 'synset_name': 'shoe.n.01'}
#
# Relations:
#
#
# --------------------
#
# it is a white van
#
# Objects:
# {'name': 'van', 'h': 134, 'object_id': 1058542, 'synsets': ['van.n.05'], 'w': 233, 'y': 298, 'x': 529}
#
# Synsets:
# {'entity_idx_start': 14, 'entity_idx_end': 17, 'entity_name': 'van', 'synset_name': 'van.n.05'}
#
# Relations:
#
#
# --------------------
#
# he has raised his chin
#
# Objects:
# {'name': 'chin', 'h': 9, 'object_id': 1058541, 'synsets': ['chin.n.01'], 'w': 11, 'y': 288, 'x': 399}
#
# Synsets:
# {'entity_idx_start': 18, 'entity_idx_end': 22, 'entity_name': 'chin', 'synset_name': 'chin.n.01'}
#
# Relations:
#
#
# --------------------
#
# it is a wall made of grey tiles
#
# Objects:
# {'name': 'wall', 'h': 533, 'object_id': 1058543, 'synsets': ['wall.n.01'], 'w': 134, 'y': 1, 'x': 0}
#
# Synsets:
# {'entity_idx_start': 26, 'entity_idx_end': 31, 'entity_name': 'tiles', 'synset_name': 'tile.n.01'}
# {'entity_idx_start': 8, 'entity_idx_end': 12, 'entity_name': 'wall', 'synset_name': 'wall.n.01'}
#
# Relations:
#
#
# --------------------
#
# man is wearing red tshirt
#
# Objects:
# {'name': 'shirt', 'h': 101, 'object_id': 1058511, 'synsets': ['shirt.n.01'], 'w': 59, 'y': 289, 'x': 241}
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
# {'synsets': ['wear.v.01'], 'predicate': 'WEARING', 'relationship_id': 3186258, 'object_id': 1058511, 'subject_id': 1058529}
#
#
# --------------------
#
# man is holding his chin
#
# Objects:
# {'name': 'chin', 'h': 9, 'object_id': 1058541, 'synsets': ['chin.n.01'], 'w': 11, 'y': 288, 'x': 399}
# {'name': 'man', 'h': 251, 'object_id': 1058532, 'synsets': ['man.n.01'], 'w': 75, 'y': 264, 'x': 372}
#
# Synsets:
# {'entity_idx_start': 19, 'entity_idx_end': 23, 'entity_name': 'chin', 'synset_name': 'chin.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'holding', 'relationship_id': 3186259, 'object_id': 1058541, 'subject_id': 1058532}
#
#
# --------------------
#
# bikes have been parked near a tree
#
# Objects:
# {'name': 'tree', 'h': 360, 'object_id': 1058545, 'synsets': ['tree.n.01'], 'w': 176, 'y': 0, 'x': 249}
# {'name': 'bikes', 'h': 35, 'object_id': 1058544, 'synsets': ['bicycle.n.01'], 'w': 40, 'y': 319, 'x': 321}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'bikes', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 30, 'entity_idx_end': 34, 'entity_name': 'tree', 'synset_name': 'tree.n.01'}
#
# Relations:
# {'synsets': ['about.r.07'], 'predicate': 'near', 'relationship_id': 3186260, 'object_id': 1058545, 'subject_id': 1058544}
#
#
# --------------------
#
# building is made of bricks
#
# Objects:
# {'name': 'building', 'h': 536, 'object_id': 1058508, 'synsets': ['building.n.01'], 'w': 218, 'y': 2, 'x': 1}
#
# Synsets:
# {'entity_idx_start': 20, 'entity_idx_end': 26, 'entity_name': 'bricks', 'synset_name': 'brick.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'building', 'synset_name': 'building.n.01'}
#
# Relations:
#
#
# --------------------
#
# man is wearing brown shoes
#
# Objects:
# {'name': 'shoes', 'h': 34, 'object_id': 1058525, 'synsets': ['shoe.n.01'], 'w': 46, 'y': 481, 'x': 391}
# {'name': 'man', 'h': 251, 'object_id': 1058532, 'synsets': ['man.n.01'], 'w': 75, 'y': 264, 'x': 372}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 21, 'entity_idx_end': 26, 'entity_name': 'shoes', 'synset_name': 'shoe.n.01'}
#
# Relations:
# {'synsets': ['wear.v.01'], 'predicate': 'WEARING', 'relationship_id': 3186261, 'object_id': 1058525, 'subject_id': 1058532}
#
#
# --------------------
#
# clock is green in colour
#
# Objects:
# {'name': 'clock', 'h': 339, 'object_id': 1058498, 'synsets': ['clock.n.01'], 'w': 79, 'y': 91, 'x': 421}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
# {'entity_idx_start': 18, 'entity_idx_end': 24, 'entity_name': 'colour', 'synset_name': 'color.n.04'}
#
# Relations:
#
#
# --------------------
#
# bikes are packed near the trees
#
# Objects:
# {'name': 'tree', 'h': 360, 'object_id': 1058545, 'synsets': ['tree.n.01'], 'w': 176, 'y': 0, 'x': 249}
# {'name': 'bikes', 'h': 35, 'object_id': 1058544, 'synsets': ['bicycle.n.01'], 'w': 40, 'y': 319, 'x': 321}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'bikes', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 26, 'entity_idx_end': 31, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
# {'synsets': ['about.r.07'], 'predicate': 'near', 'relationship_id': 3186262, 'object_id': 1058545, 'subject_id': 1058544}
#
#
# --------------------
#
# man has raised his arm
#
# Objects:
# {'name': 'arm', 'h': 43, 'object_id': 1058546, 'synsets': ['arm.n.01'], 'w': 32, 'y': 283, 'x': 368}
#
# Synsets:
# {'entity_idx_start': 19, 'entity_idx_end': 22, 'entity_name': 'arm', 'synset_name': 'arm.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# man wearing a red shirt
#
# Objects:
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
# {'name': 'shirt', 'h': 101, 'object_id': 1058511, 'synsets': ['shirt.n.01'], 'w': 59, 'y': 289, 'x': 241}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 18, 'entity_idx_end': 23, 'entity_name': 'shirt', 'synset_name': 'shirt.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'ON', 'relationship_id': 3186263, 'object_id': 1058529, 'subject_id': 1058511}
#
#
# --------------------
#
# man wearing a grey shirt
#
# Objects:
# {'name': 'shirt', 'h': 66, 'object_id': 1058547, 'synsets': ['shirt.n.01'], 'w': 37, 'y': 306, 'x': 384}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 19, 'entity_idx_end': 24, 'entity_name': 'shirt', 'synset_name': 'shirt.n.01'}
#
# Relations:
#
#
# --------------------
#
# tall green clock
#
# Objects:
# {'name': 'clock', 'h': 339, 'object_id': 1058498, 'synsets': ['clock.n.01'], 'w': 79, 'y': 91, 'x': 421}
#
# Synsets:
# {'entity_idx_start': 11, 'entity_idx_end': 16, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
#
# Relations:
#
#
# --------------------
#
# white truck parked at the curb
#
# Objects:
# {'name': 'van', 'h': 134, 'object_id': 1058542, 'synsets': ['van.n.05'], 'w': 233, 'y': 298, 'x': 529}
#
# Synsets:
# {'entity_idx_start': 26, 'entity_idx_end': 30, 'entity_name': 'curb', 'synset_name': 'curb.n.01'}
# {'entity_idx_start': 6, 'entity_idx_end': 11, 'entity_name': 'truck', 'synset_name': 'truck.n.01'}
#
# Relations:
#
#
# --------------------
#
# bicycle chained to a pole
#
# Objects:
# {'name': 'bike', 'h': 35, 'object_id': 1058535, 'synsets': ['bicycle.n.01'], 'w': 29, 'y': 319, 'x': 334}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 7, 'entity_name': 'bicycle', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 21, 'entity_idx_end': 25, 'entity_name': 'pole', 'synset_name': 'pole.n.01'}
#
# Relations:
#
#
# --------------------
#
# man is holding his chin
#
# Objects:
# {'name': 'man', 'h': 248, 'object_id': 3798576, 'synsets': ['man.n.01'], 'w': 97, 'y': 264, 'x': 362}
# {'name': 'chin', 'h': 9, 'object_id': 1058541, 'synsets': ['chin.n.01'], 'w': 11, 'y': 288, 'x': 399}
#
# Synsets:
# {'entity_idx_start': 19, 'entity_idx_end': 23, 'entity_name': 'chin', 'synset_name': 'chin.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
# {'synsets': ['have.v.01'], 'predicate': 'holding', 'relationship_id': 4265924, 'object_id': 1058541, 'subject_id': 3798576}
#
#
# --------------------
#
# man has a grey jumper
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 15, 'entity_idx_end': 21, 'entity_name': 'jumper', 'synset_name': 'sweater.n.01'}
#
# Relations:
#
#
# --------------------
#
# man is wearing glasses
#
# Objects:
# {'name': 'man', 'h': 264, 'object_id': 3798577, 'synsets': ['man.n.01'], 'w': 72, 'y': 251, 'x': 230}
# {'name': 'glasses', 'h': 12, 'object_id': 1058518, 'synsets': ['spectacles.n.01'], 'w': 20, 'y': 268, 'x': 271}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 15, 'entity_idx_end': 22, 'entity_name': 'glasses', 'synset_name': 'spectacles.n.01'}
#
# Relations:
# {'synsets': ['wear.v.01'], 'predicate': 'WEARING', 'relationship_id': 4265925, 'object_id': 1058518, 'subject_id': 3798577}
#
#
# --------------------
#
# lamp post are along the road
#
# Objects:
# {'name': 'road', 'h': 218, 'object_id': 3798578, 'synsets': ['road.n.01'], 'w': 340, 'y': 295, 'x': 435}
# {'name': 'lamp post', 'h': 430, 'object_id': 1058548, 'synsets': [], 'w': 41, 'y': 63, 'x': 537}
#
# Synsets:
# {'entity_idx_start': 24, 'entity_idx_end': 28, 'entity_name': 'road', 'synset_name': 'road.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'along', 'relationship_id': 4265926, 'object_id': 3798578, 'subject_id': 1058548}
#
#
# --------------------
#
# the man wears a red t shirt
#
# Objects:
# {'name': 'shirt', 'h': 101, 'object_id': 1058511, 'synsets': ['shirt.n.01'], 'w': 59, 'y': 289, 'x': 241}
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
# {'synsets': ['in.r.01'], 'predicate': 'IN', 'relationship_id': 3186264, 'object_id': 1058511, 'subject_id': 1058529}
#
#
# --------------------
#
# the man wears grey pants
#
# Objects:
# {'name': 'pants', 'h': 128, 'object_id': 1058531, 'synsets': ['trouser.n.01'], 'w': 54, 'y': 369, 'x': 382}
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 19, 'entity_idx_end': 24, 'entity_name': 'pants', 'synset_name': 'trouser.n.01'}
#
# Relations:
#
#
# --------------------
#
# trees are seen in the background
#
# Objects:
# {'name': 'tree', 'h': 360, 'object_id': 1058545, 'synsets': ['tree.n.01'], 'w': 176, 'y': 0, 'x': 249}
#
# Synsets:
# {'entity_idx_start': 22, 'entity_idx_end': 32, 'entity_name': 'background', 'synset_name': 'background.n.02'}
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# the man wears a grey hoodie
#
# Objects:
# {'name': 'jacket', 'h': 97, 'object_id': 1058530, 'synsets': ['jacket.n.01'], 'w': 89, 'y': 296, 'x': 356}
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# the street is clearly clean
#
# Objects:
# {'name': 'street', 'h': 233, 'object_id': 1058539, 'synsets': ['street.n.01'], 'w': 440, 'y': 283, 'x': 358}
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 10, 'entity_name': 'street', 'synset_name': 'street.n.01'}
#
# Relations:
#
#
# --------------------
#
# a parking meter is on the street
#
# Objects:
# {'name': 'street', 'h': 233, 'object_id': 1058539, 'synsets': ['street.n.01'], 'w': 440, 'y': 283, 'x': 358}
# {'name': 'parking meter', 'h': 143, 'object_id': 1058519, 'synsets': ['parking_meter.n.01'], 'w': 32, 'y': 327, 'x': 574}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 15, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
# {'entity_idx_start': 26, 'entity_idx_end': 32, 'entity_name': 'street', 'synset_name': 'street.n.01'}
#
# Relations:
# {'synsets': ['along.r.01'], 'predicate': 'on top of', 'relationship_id': 3186266, 'object_id': 1058539, 'subject_id': 1058519}
#
#
# --------------------
#
# trees line up the street
#
# Objects:
# {'name': 'street', 'h': 233, 'object_id': 1058539, 'synsets': ['street.n.01'], 'w': 440, 'y': 283, 'x': 358}
# {'name': 'tree', 'h': 360, 'object_id': 1058545, 'synsets': ['tree.n.01'], 'w': 176, 'y': 0, 'x': 249}
#
# Synsets:
# {'entity_idx_start': 18, 'entity_idx_end': 24, 'entity_name': 'street', 'synset_name': 'street.n.01'}
#
# Relations:
# {'synsets': ['next.r.01'], 'predicate': 'next to', 'relationship_id': 3186267, 'object_id': 1058539, 'subject_id': 1058545}
#
#
# --------------------
#
# a man in glasses
#
# Objects:
# {'name': 'glasses', 'h': 12, 'object_id': 1058518, 'synsets': ['spectacles.n.01'], 'w': 20, 'y': 268, 'x': 271}
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 9, 'entity_idx_end': 16, 'entity_name': 'glasses', 'synset_name': 'spectacles.n.01'}
#
# Relations:
# {'synsets': ['wear.v.01'], 'predicate': 'WEARING', 'relationship_id': 3186268, 'object_id': 1058518, 'subject_id': 1058529}
#
#
# --------------------
#
# bicycles are seen in the bckground
#
# Objects:
# {'name': 'man', 'h': 262, 'object_id': 1058529, 'synsets': ['man.n.01'], 'w': 60, 'y': 249, 'x': 238}
# {'name': 'bikes', 'h': 35, 'object_id': 1058544, 'synsets': ['bicycle.n.01'], 'w': 40, 'y': 319, 'x': 321}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'bicycles', 'synset_name': 'bicycle.n.01'}
#
# Relations:
# {'synsets': ['behind.r.01'], 'predicate': 'behind', 'relationship_id': 3186269, 'object_id': 1058529, 'subject_id': 1058544}
#
#
# --------------------
#
# trees line the sidewalk
#
# Objects:
# {'name': 'sidewalk', 'h': 266, 'object_id': 1058534, 'synsets': ['sidewalk.n.01'], 'w': 722, 'y': 331, 'x': 77}
# {'name': 'trees', 'h': 557, 'object_id': 1058549, 'synsets': ['tree.n.01'], 'w': 606, 'y': 0, 'x': 190}
#
# Synsets:
# {'entity_idx_start': 15, 'entity_idx_end': 23, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
# {'synsets': ['by.r.01'], 'predicate': 'by', 'relationship_id': 3186270, 'object_id': 1058534, 'subject_id': 1058549}
#
#
# --------------------
#
# sidewalk is made of bricks
#
# Objects:
# {'name': 'sidewalk', 'h': 266, 'object_id': 1058534, 'synsets': ['sidewalk.n.01'], 'w': 722, 'y': 331, 'x': 77}
#
# Synsets:
# {'entity_idx_start': 20, 'entity_idx_end': 26, 'entity_name': 'bricks', 'synset_name': 'brick.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# cars are parked along the edge of the street
#
# Objects:
# {'name': 'car', 'h': 174, 'object_id': 1058515, 'synsets': ['car.n.01'], 'w': 91, 'y': 342, 'x': 708}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 4, 'entity_name': 'cars', 'synset_name': 'car.n.01'}
# {'entity_idx_start': 26, 'entity_idx_end': 30, 'entity_name': 'edge', 'synset_name': 'edge.n.01'}
# {'entity_idx_start': 38, 'entity_idx_end': 44, 'entity_name': 'street', 'synset_name': 'street.n.01'}
#
# Relations:
#
#
# --------------------
#
# parking meter has an orange top
#
# Objects:
# {'name': 'parking meter', 'h': 143, 'object_id': 1058519, 'synsets': ['parking_meter.n.01'], 'w': 32, 'y': 327, 'x': 574}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 13, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
#
# Relations:
#
#
# --------------------
#
# guy is wearing black pants
#
# Objects:
# {'name': 'pants', 'h': 118, 'object_id': 1058528, 'synsets': ['trouser.n.01'], 'w': 38, 'y': 384, 'x': 245}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'guy', 'synset_name': 'guy.n.01'}
# {'entity_idx_start': 21, 'entity_idx_end': 26, 'entity_name': 'pants', 'synset_name': 'trouser.n.01'}
#
# Relations:
#
#
# --------------------
#
# A man in a gray hoodie
#
# Objects:
# {'name': 'jacket', 'h': 97, 'object_id': 1058530, 'synsets': ['jacket.n.01'], 'w': 89, 'y': 296, 'x': 356}
# {'name': 'man', 'h': 251, 'object_id': 1058532, 'synsets': ['man.n.01'], 'w': 75, 'y': 264, 'x': 372}
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
# {'synsets': ['wear.v.01'], 'predicate': 'WEARING', 'relationship_id': 3186271, 'object_id': 1058530, 'subject_id': 1058532}
#
#
# --------------------
#
# Trees with sparse foilage
#
# Objects:
# {'name': 'trees', 'h': 557, 'object_id': 1058549, 'synsets': ['tree.n.01'], 'w': 606, 'y': 0, 'x': 190}
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'Trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# A white Ford utility truck
#
# Objects:
# {'name': 'work truck', 'h': 185, 'object_id': 1058536, 'synsets': [], 'w': 265, 'y': 271, 'x': 521}
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# A tall brick building with many windows
#
# Objects:
# {'name': 'windows', 'h': 148, 'object_id': 3798579, 'synsets': ['window.n.01'], 'w': 173, 'y': 4, 'x': 602}
# {'name': 'building', 'h': 536, 'object_id': 1058508, 'synsets': ['building.n.01'], 'w': 218, 'y': 2, 'x': 1}
#
# Synsets:
# {'entity_idx_start': 32, 'entity_idx_end': 39, 'entity_name': 'windows', 'synset_name': 'window.n.01'}
#
# Relations:
# {'synsets': [], 'predicate': 'with', 'relationship_id': 4265927, 'object_id': 3798579, 'subject_id': 1058508}
#
#
# --------------------
#
# trees are next to were they are standing
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# bikes have been parked near the road
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'bikes', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 32, 'entity_idx_end': 36, 'entity_name': 'road', 'synset_name': 'road.n.01'}
#
# Relations:
#
#
# --------------------
#
# white building is at the back
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 25, 'entity_idx_end': 29, 'entity_name': 'back', 'synset_name': 'back.n.01'}
# {'entity_idx_start': 6, 'entity_idx_end': 14, 'entity_name': 'building', 'synset_name': 'building.n.01'}
#
# Relations:
#
#
# --------------------
#
# two lights have been on
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 10, 'entity_name': 'lights', 'synset_name': 'light.n.02'}
#
# Relations:
#
#
# --------------------
#
# man has hands in pocket
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 13, 'entity_name': 'hands', 'synset_name': 'hand.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 17, 'entity_idx_end': 23, 'entity_name': 'pocket', 'synset_name': 'pocket.n.01'}
#
# Relations:
#
#
# --------------------
#
# bikes are parked next to a tree
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'bikes', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 27, 'entity_idx_end': 31, 'entity_name': 'tree', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# building is painted white
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'building', 'synset_name': 'building.n.01'}
#
# Relations:
#
#
# --------------------
#
# tree has no leaves
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 12, 'entity_idx_end': 18, 'entity_name': 'leaves', 'synset_name': 'leaf.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 4, 'entity_name': 'tree', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# bikes are parked on the far end
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'bikes', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 28, 'entity_idx_end': 31, 'entity_name': 'end', 'synset_name': 'end.n.01'}
#
# Relations:
#
#
# --------------------
#
# lamp stands are along the road
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 26, 'entity_idx_end': 30, 'entity_name': 'road', 'synset_name': 'road.n.01'}
#
# Relations:
#
#
# --------------------
#
# car has a black tire
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'car', 'synset_name': 'car.n.01'}
# {'entity_idx_start': 16, 'entity_idx_end': 20, 'entity_name': 'tire', 'synset_name': 'tire.n.01'}
#
# Relations:
#
#
# --------------------
#
# headlights of the car are off
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 18, 'entity_idx_end': 21, 'entity_name': 'car', 'synset_name': 'car.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 10, 'entity_name': 'headlights', 'synset_name': 'headlight.n.01'}
#
# Relations:
#
#
# --------------------
#
# building has a white paint
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'building', 'synset_name': 'building.n.01'}
# {'entity_idx_start': 21, 'entity_idx_end': 26, 'entity_name': 'paint', 'synset_name': 'paint.n.01'}
#
# Relations:
#
#
# --------------------
#
# man has hand on pocket
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 12, 'entity_name': 'hand', 'synset_name': 'hand.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 16, 'entity_idx_end': 22, 'entity_name': 'pocket', 'synset_name': 'pocket.n.01'}
#
# Relations:
#
#
# --------------------
#
# side walk is made of bricks
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 21, 'entity_idx_end': 27, 'entity_name': 'bricks', 'synset_name': 'brick.n.01'}
#
# Relations:
#
#
# --------------------
#
# two lights are on
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 10, 'entity_name': 'lights', 'synset_name': 'light.n.02'}
#
# Relations:
#
#
# --------------------
#
# two men are talking
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'men', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# one man is wearing grey jumper
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 24, 'entity_idx_end': 30, 'entity_name': 'jumper', 'synset_name': 'sweater.n.01'}
#
# Relations:
#
#
# --------------------
#
# clock is painted green
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
#
# Relations:
#
#
# --------------------
#
# white van is parked near the road
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 29, 'entity_idx_end': 33, 'entity_name': 'road', 'synset_name': 'road.n.01'}
# {'entity_idx_start': 6, 'entity_idx_end': 9, 'entity_name': 'van', 'synset_name': 'van.n.05'}
#
# Relations:
#
#
# --------------------
#
# tree has shadows on it
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 9, 'entity_idx_end': 16, 'entity_name': 'shadows', 'synset_name': 'shadow.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 4, 'entity_name': 'tree', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# white vehicle has been parked
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 6, 'entity_idx_end': 13, 'entity_name': 'vehicle', 'synset_name': 'vehicle.n.01'}
#
# Relations:
#
#
# --------------------
#
# two lights are on on the building
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 25, 'entity_idx_end': 33, 'entity_name': 'building', 'synset_name': 'building.n.01'}
# {'entity_idx_start': 4, 'entity_idx_end': 10, 'entity_name': 'lights', 'synset_name': 'light.n.02'}
#
# Relations:
#
#
# --------------------
#
# a clock is next to were the men are standing
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 7, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
# {'entity_idx_start': 28, 'entity_idx_end': 31, 'entity_name': 'men', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# a brown building opposite were the men are standing
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 35, 'entity_idx_end': 38, 'entity_name': 'men', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# a red car is at the back
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 20, 'entity_idx_end': 24, 'entity_name': 'back', 'synset_name': 'back.n.01'}
# {'entity_idx_start': 6, 'entity_idx_end': 9, 'entity_name': 'car', 'synset_name': 'car.n.01'}
#
# Relations:
#
#
# --------------------
#
# electric post near the men
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 23, 'entity_idx_end': 26, 'entity_name': 'men', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 9, 'entity_idx_end': 13, 'entity_name': 'post', 'synset_name': 'post.n.01'}
#
# Relations:
#
#
# --------------------
#
# man is wearing sneakers
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 15, 'entity_idx_end': 23, 'entity_name': 'sneakers', 'synset_name': 'gym_shoe.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# man is wearing black pants
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 21, 'entity_idx_end': 26, 'entity_name': 'pants', 'synset_name': 'trouser.n.01'}
#
# Relations:
#
#
# --------------------
#
# man is wearing glasses
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 15, 'entity_idx_end': 22, 'entity_name': 'glasses', 'synset_name': 'spectacles.n.01'}
#
# Relations:
#
#
# --------------------
#
# it is an orange tshirt
#
# Objects:
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# a white car parked
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 11, 'entity_name': 'car', 'synset_name': 'car.n.01'}
#
# Relations:
#
#
# --------------------
#
# a white brick wall
#
# Objects:
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# it is a blue sky
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 13, 'entity_idx_end': 16, 'entity_name': 'sky', 'synset_name': 'sky.n.01'}
#
# Relations:
#
#
# --------------------
#
# man has brown shoes
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 14, 'entity_idx_end': 19, 'entity_name': 'shoes', 'synset_name': 'shoe.n.01'}
#
# Relations:
#
#
# --------------------
#
# White car parked by curb
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 20, 'entity_idx_end': 24, 'entity_name': 'curb', 'synset_name': 'curb.n.01'}
#
# Relations:
#
#
# --------------------
#
# White canopy on brick building
#
# Objects:
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# Row of trees on right side of road
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 30, 'entity_idx_end': 34, 'entity_name': 'road', 'synset_name': 'road.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'Row', 'synset_name': 'row.n.01'}
# {'entity_idx_start': 22, 'entity_idx_end': 26, 'entity_name': 'side', 'synset_name': 'side.n.01'}
# {'entity_idx_start': 7, 'entity_idx_end': 12, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# Red vehicle parked next to curb
#
# Objects:
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# Man wearing grey hoodie
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'Man', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# man in red shirt
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 11, 'entity_idx_end': 16, 'entity_name': 'shirt', 'synset_name': 'shirt.n.01'}
#
# Relations:
#
#
# --------------------
#
# man in grey hoodie
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# store inside white brick building
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'store', 'synset_name': 'shop.n.01'}
#
# Relations:
#
#
# --------------------
#
# parked white pickup truck
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 13, 'entity_idx_end': 25, 'entity_name': 'pickup truck', 'synset_name': 'pickup.n.01'}
#
# Relations:
#
#
# --------------------
#
# older style coin fed parking meter
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 21, 'entity_idx_end': 34, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
#
# Relations:
#
#
# --------------------
#
# the photo was taken during the day
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 31, 'entity_idx_end': 34, 'entity_name': 'day', 'synset_name': 'day.n.01'}
# {'entity_idx_start': 4, 'entity_idx_end': 9, 'entity_name': 'photo', 'synset_name': 'photograph.n.01'}
#
# Relations:
#
#
# --------------------
#
# the day was sunny
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'day', 'synset_name': 'day.n.01'}
#
# Relations:
#
#
# --------------------
#
# the men are on the sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'men', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 19, 'entity_idx_end': 27, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# there is a big clock on the pole
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 15, 'entity_idx_end': 20, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
# {'entity_idx_start': 28, 'entity_idx_end': 32, 'entity_name': 'pole', 'synset_name': 'pole.n.01'}
#
# Relations:
#
#
# --------------------
#
# the trees do not have leaves
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 22, 'entity_idx_end': 28, 'entity_name': 'leaves', 'synset_name': 'leaf.n.01'}
# {'entity_idx_start': 4, 'entity_idx_end': 9, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# cars are parked on the side of the road
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 4, 'entity_name': 'cars', 'synset_name': 'car.n.01'}
# {'entity_idx_start': 35, 'entity_idx_end': 39, 'entity_name': 'road', 'synset_name': 'road.n.01'}
# {'entity_idx_start': 23, 'entity_idx_end': 27, 'entity_name': 'side', 'synset_name': 'side.n.01'}
#
# Relations:
#
#
# --------------------
#
# two men standing on the road
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'men', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 24, 'entity_idx_end': 28, 'entity_name': 'road', 'synset_name': 'road.n.01'}
#
# Relations:
#
#
# --------------------
#
# a clock on a green pole
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 7, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
# {'entity_idx_start': 19, 'entity_idx_end': 23, 'entity_name': 'pole', 'synset_name': 'pole.n.01'}
#
# Relations:
#
#
# --------------------
#
# a white brick wall
#
# Objects:
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# two lights are lit
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 10, 'entity_name': 'lights', 'synset_name': 'light.n.02'}
#
# Relations:
#
#
# --------------------
#
# bikes have been parked along the road
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'bikes', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 33, 'entity_idx_end': 37, 'entity_name': 'road', 'synset_name': 'road.n.01'}
#
# Relations:
#
#
# --------------------
#
# drainage were the men are standing
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'drainage', 'synset_name': 'drain.n.01'}
# {'entity_idx_start': 18, 'entity_idx_end': 21, 'entity_name': 'men', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# trees are along the road
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 20, 'entity_idx_end': 24, 'entity_name': 'road', 'synset_name': 'road.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# white car has been parked were they are standing
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 6, 'entity_idx_end': 9, 'entity_name': 'car', 'synset_name': 'car.n.01'}
#
# Relations:
#
#
# --------------------
#
# overhead lights are glowing orange
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 9, 'entity_idx_end': 15, 'entity_name': 'lights', 'synset_name': 'light.n.02'}
#
# Relations:
#
#
# --------------------
#
# white car parked next to the sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 6, 'entity_idx_end': 9, 'entity_name': 'car', 'synset_name': 'car.n.01'}
# {'entity_idx_start': 29, 'entity_idx_end': 37, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# man is wearing grey sweatshirt
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 20, 'entity_idx_end': 30, 'entity_name': 'sweatshirt', 'synset_name': 'sweatshirt.n.01'}
#
# Relations:
#
#
# --------------------
#
# tree is casting a shadow on the sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 18, 'entity_idx_end': 24, 'entity_name': 'shadow', 'synset_name': 'shadow.n.01'}
# {'entity_idx_start': 32, 'entity_idx_end': 40, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
# ...
#
#
# --------------------
#
# the man is in black pants
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 20, 'entity_idx_end': 25, 'entity_name': 'pants', 'synset_name': 'trouser.n.01'}
#
# Relations:
#
#
# --------------------
#
# the parking meter is on the sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 17, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
# {'entity_idx_start': 28, 'entity_idx_end': 36, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# the man is in a red shirt
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 20, 'entity_idx_end': 25, 'entity_name': 'shirt', 'synset_name': 'shirt.n.01'}
#
# Relations:
#
#
# --------------------
#
# two lights are switched on
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 10, 'entity_name': 'lights', 'synset_name': 'light.n.02'}
#
# Relations:
#
#
# --------------------
#
# the clock pole is green
#
# Objects:
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# the shoes are grey
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 9, 'entity_name': 'shoes', 'synset_name': 'shoe.n.01'}
#
# Relations:
#
#
# --------------------
#
# the man is in a grey hoodie
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# trees are on the sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 17, 'entity_idx_end': 25, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# two men stand on an urban sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'men', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 26, 'entity_idx_end': 34, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# a large clock on a green post
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 13, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
# {'entity_idx_start': 25, 'entity_idx_end': 29, 'entity_name': 'post', 'synset_name': 'post.n.01'}
#
# Relations:
#
#
# --------------------
#
# parking meter next to the curb
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 26, 'entity_idx_end': 30, 'entity_name': 'curb', 'synset_name': 'curb.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 13, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
#
# Relations:
#
#
# --------------------
#
# white pick-up truck
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 14, 'entity_idx_end': 19, 'entity_name': 'truck', 'synset_name': 'truck.n.01'}
#
# Relations:
#
#
# --------------------
#
# trees just beginning to bud in spring
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 31, 'entity_idx_end': 37, 'entity_name': 'spring', 'synset_name': 'spring.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# man with a gray, unzipped sweatchirt
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'man', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# bicycle tied to a post
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 7, 'entity_name': 'bicycle', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 18, 'entity_idx_end': 22, 'entity_name': 'post', 'synset_name': 'post.n.01'}
#
# Relations:
#
#
# --------------------
#
# back of a white sedan
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 16, 'entity_idx_end': 21, 'entity_name': 'sedan', 'synset_name': 'sedan.n.01'}
#
# Relations:
#
#
# --------------------
#
# street lamp at curb side
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 11, 'entity_name': 'street lamp', 'synset_name': 'streetlight.n.01'}
#
# Relations:
#
#
# --------------------
#
# sign above building entrance
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 4, 'entity_name': 'sign', 'synset_name': 'sign.n.02'}
#
# Relations:
#
#
# --------------------
#
# there are two men conversing in the photo
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 14, 'entity_idx_end': 17, 'entity_name': 'men', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 36, 'entity_idx_end': 41, 'entity_name': 'photo', 'synset_name': 'photograph.n.01'}
#
# Relations:
#
#
# --------------------
#
# this is an outdoor picture
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 19, 'entity_idx_end': 26, 'entity_name': 'picture', 'synset_name': 'picture.n.01'}
#
# Relations:
#
#
# --------------------
#
# there is a bicycle in the photo
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 11, 'entity_idx_end': 18, 'entity_name': 'bicycle', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 26, 'entity_idx_end': 31, 'entity_name': 'photo', 'synset_name': 'photograph.n.01'}
#
# Relations:
#
#
# --------------------
#
# shadows are cast
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 7, 'entity_name': 'shadows', 'synset_name': 'shadow.n.01'}
#
# Relations:
#
#
# --------------------
#
# there are buildings in the photo
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 10, 'entity_idx_end': 19, 'entity_name': 'buildings', 'synset_name': 'building.n.01'}
# {'entity_idx_start': 27, 'entity_idx_end': 32, 'entity_name': 'photo', 'synset_name': 'photograph.n.01'}
#
# Relations:
#
#
# --------------------
#
#  green pole is in the photo
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 22, 'entity_idx_end': 27, 'entity_name': 'photo', 'synset_name': 'photograph.n.01'}
# {'entity_idx_start': 7, 'entity_idx_end': 11, 'entity_name': 'pole', 'synset_name': 'pole.n.01'}
#
# Relations:
#
#
# --------------------
#
# some trees hAVE NO LEAVES
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 16, 'entity_idx_end': 18, 'entity_name': 'NO', 'synset_name': 'no.n.01'}
# {'entity_idx_start': 5, 'entity_idx_end': 10, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# the two men are talking
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 11, 'entity_name': 'men', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# a white truck is parked
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 13, 'entity_name': 'truck', 'synset_name': 'truck.n.01'}
#
# Relations:
#
#
# --------------------
#
# A parking meter with a yellow top
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 15, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
#
# Relations:
#
#
# --------------------
#
# the bottom of a tree
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 10, 'entity_name': 'bottom', 'synset_name': 'bottom.n.01'}
# {'entity_idx_start': 16, 'entity_idx_end': 20, 'entity_name': 'tree', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# a man in a grey sweater
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 16, 'entity_idx_end': 23, 'entity_name': 'sweater', 'synset_name': 'sweater.n.01'}
#
# Relations:
#
#
# --------------------
#
# the tires from two bikes
#
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 19, 'entity_idx_end': 24, 'entity_name': 'bikes', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 4, 'entity_idx_end': 9, 'entity_name': 'tires', 'synset_name': 'tire.n.01'}
#
# Relations:
#
#
# --------------------
#
# a white pick up truck
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 12, 'entity_name': 'pick', 'synset_name': 'choice.n.01'}
# {'entity_idx_start': 16, 'entity_idx_end': 21, 'entity_name': 'truck', 'synset_name': 'truck.n.01'}
#
# Relations:
#
#
# --------------------
#
# a partially blocked green clock
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 26, 'entity_idx_end': 31, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
#
# Relations:
#
#
# --------------------
#
# an unreadable store sign
#
# Objects:
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# a brown street lamp with a glass top
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 19, 'entity_name': 'street lamp', 'synset_name': 'streetlight.n.01'}
#
# Relations:
#
#
# --------------------
#
# the rear of a white car
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 20, 'entity_idx_end': 23, 'entity_name': 'car', 'synset_name': 'car.n.01'}
# {'entity_idx_start': 4, 'entity_idx_end': 8, 'entity_name': 'rear', 'synset_name': 'rear.n.01'}
#
# Relations:
#
#
# --------------------
#
# two men having a conversation
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 17, 'entity_idx_end': 29, 'entity_name': 'conversation', 'synset_name': 'conversation.n.01'}
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'men', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# large ornate clock on sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 13, 'entity_idx_end': 18, 'entity_name': 'clock', 'synset_name': 'clock.n.01'}
# {'entity_idx_start': 22, 'entity_idx_end': 30, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# large moss covered tree
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 6, 'entity_idx_end': 10, 'entity_name': 'moss', 'synset_name': 'moss.n.01'}
# {'entity_idx_start': 19, 'entity_idx_end': 23, 'entity_name': 'tree', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# truck with racks parked next to curb
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 11, 'entity_idx_end': 16, 'entity_name': 'racks', 'synset_name': 'rack.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'truck', 'synset_name': 'truck.n.01'}
#
# Relations:
#
#
# --------------------
#
# parking meter on sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 13, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
# {'entity_idx_start': 17, 'entity_idx_end': 25, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# tree with sparse leaves
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 17, 'entity_idx_end': 23, 'entity_name': 'leaves', 'synset_name': 'leaf.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 4, 'entity_name': 'tree', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# street light on wooden pole
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 23, 'entity_idx_end': 27, 'entity_name': 'pole', 'synset_name': 'pole.n.01'}
#
# Relations:
#
#
# --------------------
#
# brick wall of a building
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 16, 'entity_idx_end': 24, 'entity_name': 'building', 'synset_name': 'building.n.01'}
#
# Relations:
#
#
# --------------------
#
# sidewalk paved with bricks
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 20, 'entity_idx_end': 26, 'entity_name': 'bricks', 'synset_name': 'brick.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# yellow car in the road
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 7, 'entity_idx_end': 10, 'entity_name': 'car', 'synset_name': 'car.n.01'}
# {'entity_idx_start': 18, 'entity_idx_end': 22, 'entity_name': 'road', 'synset_name': 'road.n.01'}
#
# Relations:
#
#
# --------------------
#
# A man in a red long-sleeved shirt
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 2, 'entity_idx_end': 5, 'entity_name': 'man', 'synset_name': 'man.n.01'}
# {'entity_idx_start': 28, 'entity_idx_end': 33, 'entity_name': 'shirt', 'synset_name': 'shirt.n.01'}
#
# Relations:
#
#
# --------------------
#
# Shadows on side of building
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 19, 'entity_idx_end': 27, 'entity_name': 'building', 'synset_name': 'building.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 7, 'entity_name': 'Shadows', 'synset_name': 'shadow.n.01'}
# {'entity_idx_start': 11, 'entity_idx_end': 15, 'entity_name': 'side', 'synset_name': 'side.n.01'}
#
# Relations:
#
#
# --------------------
#
# A tree on the sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 14, 'entity_idx_end': 22, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
# {'entity_idx_start': 2, 'entity_idx_end': 6, 'entity_name': 'tree', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# Cars parked on side of the street
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 4, 'entity_name': 'Cars', 'synset_name': 'car.n.01'}
# {'entity_idx_start': 15, 'entity_idx_end': 19, 'entity_name': 'side', 'synset_name': 'side.n.01'}
# {'entity_idx_start': 27, 'entity_idx_end': 33, 'entity_name': 'street', 'synset_name': 'street.n.01'}
#
# Relations:
#
#
# --------------------
#
# Two men talking to each other
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'men', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# Pavers are on the ground
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 18, 'entity_idx_end': 24, 'entity_name': 'ground', 'synset_name': 'land.n.04'}
#
# Relations:
#
#
# --------------------
#
# Man wears sneakers
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 10, 'entity_idx_end': 18, 'entity_name': 'sneakers', 'synset_name': 'gym_shoe.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 3, 'entity_name': 'Man', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# A tree bare of leaves
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 15, 'entity_idx_end': 21, 'entity_name': 'leaves', 'synset_name': 'leaf.n.01'}
# {'entity_idx_start': 2, 'entity_idx_end': 6, 'entity_name': 'tree', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# A white truck
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 8, 'entity_idx_end': 13, 'entity_name': 'truck', 'synset_name': 'truck.n.01'}
#
# Relations:
#
#
# --------------------
#
# Bicycles are parked on the sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'Bicycles', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 27, 'entity_idx_end': 35, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# two men standing facing one another
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 4, 'entity_idx_end': 7, 'entity_name': 'men', 'synset_name': 'man.n.01'}
#
# Relations:
#
#
# --------------------
#
# bicycle parked on the sidewalk
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 0, 'entity_idx_end': 7, 'entity_name': 'bicycle', 'synset_name': 'bicycle.n.01'}
# {'entity_idx_start': 22, 'entity_idx_end': 30, 'entity_name': 'sidewalk', 'synset_name': 'sidewalk.n.01'}
#
# Relations:
#
#
# --------------------
#
# vehicles parked on the street
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 23, 'entity_idx_end': 29, 'entity_name': 'street', 'synset_name': 'street.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 8, 'entity_name': 'vehicles', 'synset_name': 'vehicle.n.01'}
#
# Relations:
#
#
# --------------------
#
# parking meter on the curb
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 21, 'entity_idx_end': 25, 'entity_name': 'curb', 'synset_name': 'curb.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 13, 'entity_name': 'parking meter', 'synset_name': 'parking_meter.n.01'}
#
# Relations:
#
#
# --------------------
#
# white brick building with black sign
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 32, 'entity_idx_end': 36, 'entity_name': 'sign', 'synset_name': 'sign.n.02'}
#
# Relations:
#
#
# --------------------
#
# tall green metal clock on a post
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 28, 'entity_idx_end': 32, 'entity_name': 'post', 'synset_name': 'post.n.01'}
#
# Relations:
#
#
# --------------------
#
# tall metal light post
#
# Objects:
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# trees lining the street
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 17, 'entity_idx_end': 23, 'entity_name': 'street', 'synset_name': 'street.n.01'}
# {'entity_idx_start': 0, 'entity_idx_end': 5, 'entity_name': 'trees', 'synset_name': 'tree.n.01'}
#
# Relations:
#
#
# --------------------
#
# brick sidewalk
#
# Objects:
#
# Synsets:
#
# Relations:
#
#
# --------------------
#
# tall buildings with many windows
#
# Objects:
#
# Synsets:
# {'entity_idx_start': 5, 'entity_idx_end': 14, 'entity_name': 'buildings', 'synset_name': 'building.n.01'}
# {'entity_idx_start': 25, 'entity_idx_end': 32, 'entity_name': 'windows', 'synset_name': 'window.n.01'}
#
# Relations:
#
#
# --------------------

# %% [markdown]
# #### Map Names (synset → entities)

# %%
synset2names = {}

for d in raw_data:
    for x in d['regions']:
        for s in x['synsets']:
            # Entity Name
            name = s['entity_name']
            # Lowercase
            name = name.lower()

            if s['synset_name'] not in synset2names:
                synset2names[s['synset_name']] = set()

            synset2names[s['synset_name']].add(name)

sum([len(v) for k,v in synset2names.items()]), len(synset2names)
# Out:
# (19440, 11930)

# %%
synset2names = OrderedDict(sorted(synset2names.items()))

# for syn, names in synset2names.items():
#     print(syn, names)

synset2names = {syn: list(names) for syn, names in synset2names.items()}

# save_json(synset2names, path='./temp/syn2ent.json')

# %%
synset_freq = []

for d in raw_data:
    for x in d['regions']:
        for s in x['synsets']:
            synset_freq.append(s['synset_name'])

synset_freq = Counter(synset_freq)
synset_freq = sorted(synset_freq.items(), key=lambda x: x[1], reverse=True)
synset_freq = OrderedDict(synset_freq)

# save_json(synset_freq, path='./temp/syn_freq.json')

# %%
_f = [f for s, f in synset_freq]
print('Freq: {:.2f} ({:.2f})'.format(np.mean(_f), np.std(_f)))

# %% [raw]
# -------------------------------------------------------------------

# %% [markdown]
# <br>
# <br>
#
# ## Attributes Data

# %%
raw_data = read_json(osj(DATA_DIR, 'attributes.json'))

# %%
objs_img = [len(d['attributes']) for d in tqdm(raw_data)]

_ = int(np.mean(objs_img))
__ = int(np.std(objs_img))

f"Objects per Image: µ = {_}, σ = {__}"
# Out:
# 100%|██████████| 108077/108077 [00:00<00:00, 2019980.19it/s]
# 'Objects per Image: µ = 35, σ = 20'

# %%
attrs_img = []

for d in tqdm(raw_data):
    num_attrs = 0
    for x in d['attributes']:
        if 'attributes' in x:
            num_attrs += 1

    attrs_img.append(num_attrs)

_ = int(np.mean(attrs_img))
__ = int(np.std(attrs_img))

f"Attributes per Image: µ = {_}, σ = {__}"
# Out:
# 100%|██████████| 108077/108077 [00:00<00:00, 228233.39it/s]
# 'Attributes per Image: µ = 15, σ = 9'

# %%
# Explore an Image

_idx = 2

d = raw_data[_idx]['attributes']

for x in d:
    name = x['names'][0]
    if 'attributes' in x:
        print(name, ': ', x['attributes'])
    else:
        print(name)
# Out:
# office phone :  ['multi-line phone']
# outlet :  ['electrical']
# outlet :  ['data line']
# keyboard :  ['white']
# monitor :  ['white', 'switched off', 'turned off']
# cpu :  ['computer tower']
# desktop :  ['curved']
# filing cabinet
# drawer
# drawer
# computer case :  ['black', 'leather']
# mouse :  ['white']
# wireless phone
# office phone base
# desk
# multiple outlet
# plug
# plug
# plug
# plug
# girl :  ['sitting']
# monitor :  ['off']
# wall
# hair :  ['long']
# chain
# pen :  ['blue', 'yellow', 'black']
# cable
# floor
# cable
# pluged
# bag :  ['black']
# wall
# black hair
# telephone :  ['black']
# white top
# strap :  ['black']
# cubicles
# dividing screen
# picture
# picture :  ['hanged']
# computer
# cables
# wall
# photos
# table :  ['white']
# handle
# floor
# necklace
# grey keys
# desk
# computer tower
# cabinet :  ['grey', 'beige']

# %%
_names = []

multi_name_data = []

for d in raw_data:
    for x in d['attributes']:
        n = x['names']
        if len(n) > 1:
            multi_name_data.append(x)
        _names.append(len(n))

_ = np.mean(_names)
__ = np.std(_names)

f"Names per sample: µ = {_:.2f}, σ = {__:.2f}"
# Out:
# 'Names per sample: µ = 1.02, σ = 0.19'

# %% [markdown]
# #### Map Attributes (one:many) → Object: Attributes

# %%
obj2attr = {}

for d in raw_data:
    for x in d['attributes']:
        if 'attributes' in x:
            for name in x['names']:
                if name not in obj2attr:
                    obj2attr[name] = set()
                for attr in x['attributes']:
                    attr = attr.lower()
                    obj2attr[name].add(attr)

_attr_per_obj = [len(a) for o, a in obj2attr.items()]

# Sort by num attributes
obj2attr = OrderedDict(sorted(obj2attr.items(), key=lambda x: len(x[1])))

_ = np.mean(_attr_per_obj)
__ = np.std(_attr_per_obj)

f"Attributes per Object: µ = {_:.2f}, σ = {__:.2f}"
# Out:
# 'Attributes per Object: µ = 8.08, σ = 53.75'

# %% [markdown]
# #### Filter Objects with ConceptNet

# %%
# save_json(obj2attr_cn, path='./temp/object_with_attr_conceptnet.json')
# Out:
# 'TODO'

# %%
# Sort objects based on entropy (skewness) of color (i.e. school bus > jeans)
